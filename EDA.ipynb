# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('data/train/2020-05-15-US-MTV-1/GooglePixel4XL/ground_truth.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3362 entries, 0 to 3361
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MessageType       3362 non-null   object
#  1   Provider          3362 non-null   object
#  2   LatitudeDegrees   3362 non-null   float64
#  3   LongitudeDegrees  3362 non-null   float64
#  4   AltitudeMeters    0 non-null      float64
#  5   SpeedMps          3362 non-null   float64
#  6   AccuracyMeters    3362 non-null   float64
#  7   BearingDegrees    3362 non-null   float64
#  8   UnixTimeMillis    3362 non-null   int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 236.5+ KB

# %%
df1.describe()
# Out:
#        LatitudeDegrees  LongitudeDegrees  AltitudeMeters     SpeedMps  \
# count      3362.000000       3362.000000             0.0  3362.000000
# mean         37.451073       -122.198970             NaN    18.451566
# std           0.086426          0.136324             NaN    13.183911
# min          37.332918       -122.433182             NaN     0.000000
# 25%          37.401378       -122.331052             NaN     0.003546
# 50%          37.416619       -122.135710             NaN    25.870860
# 75%          37.502540       -122.082065             NaN    29.177857
# max          37.633192       -122.058927             NaN    37.115963
#
#        AccuracyMeters  BearingDegrees  UnixTimeMillis
# count    3.362000e+03     3362.000000    3.362000e+03
# mean     1.000000e-01      221.201778    1.589575e+12
# std      2.359575e-15      105.696572    9.706701e+05
# min      1.000000e-01        0.223541    1.589574e+12
# 25%      1.000000e-01       92.968930    1.589575e+12
# ...

# %% [markdown]
# Zieldaten

# %%
df2=pd.read_csv('data/train/2020-05-15-US-MTV-1/GooglePixel4XL/device_imu.csv')

# %%
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734856 entries, 0 to 734855
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   MessageType    734856 non-null  object
#  1   utcTimeMillis  734856 non-null  int64
#  2   MeasurementX   734856 non-null  float64
#  3   MeasurementY   734856 non-null  float64
#  4   MeasurementZ   734856 non-null  float64
#  5   BiasX          734856 non-null  float64
#  6   BiasY          734856 non-null  float64
#  7   BiasZ          734856 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 44.9+ MB
#   MessageType  utcTimeMillis  MeasurementX  MeasurementY  MeasurementZ  \
# 0  UncalAccel  1589573679447      0.237913      9.250001      1.784781
# 1   UncalGyro  1589573679450     -0.022198      0.004974      0.014298
# 2    UncalMag  1589573679450      2.812906    -37.320263     -1.189655
# ...

# %%
df3=pd.read_csv('data/train/2020-05-15-US-MTV-1/GooglePixel4XL/device_gnss.csv')

# %%
df3.info()
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90153 entries, 0 to 90152
# Data columns (total 47 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   MessageType                                90153 non-null  object
#  1   utcTimeMillis                              90153 non-null  int64
#  2   TimeNanos                                  90153 non-null  int64
#  3   LeapSecond                                 0 non-null      float64
#  4   FullBiasNanos                              90153 non-null  int64
#  5   BiasNanos                                  90153 non-null  float64
#  6   BiasUncertaintyNanos                       90153 non-null  float64
#  7   DriftNanosPerSecond                        90153 non-null  float64
#  8   DriftUncertaintyNanosPerSecond             90153 non-null  float64
#  9   HardwareClockDiscontinuityCount            90153 non-null  int64
# ...

# %% [markdown]
# utcTimeMillis is in df2 and df3

# %%
print(df2.utcTimeMillis.nunique(), df3.utcTimeMillis.nunique())
# Out:
# 688437 3362
